# %% [markdown]
# # Colombia

# %%
import requests
import pandas as pd
import csv
import datetime
import reverse_geocoder as rg

# %%
# URL de la API
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query'

# Parámetros de la consulta
params = {
    'format': 'geojson',
    'starttime': '1990-01-01',
    'endtime': '2023-06-28',
    'minmagnitude': '2.5',
    'minlatitude': '-5.266',
    'maxlatitude': '15.708',
    'minlongitude': '276.328',
    'maxlongitude': '293.906',
    'limit': 20000
}

# Realizar la solicitud GET a la API
response = requests.get(url, params=params)

# Obtener los datos en formato JSON
data = response.json()
# Crear una lista vacía para almacenar los registros
records = []

# Recorrer los eventos y extraer los parámetros
for event in data['features']:
    properties = event['properties']
    latitude = event['geometry']['coordinates'][1]
    longitude = event['geometry']['coordinates'][0]
    records.append(properties)

for event in data['features']:
    properties = event['properties']
    coordinates = event['geometry']['coordinates']
    properties['latitude'] = coordinates[1]
    properties['longitude'] = coordinates[0]
    records.append(properties)

# Crear el DataFrame
df_Colombia = pd.DataFrame(records)

df_Colombia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14648 entries, 0 to 14647
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mag        14648 non-null  float64
#  1   place      14616 non-null  object
#  2   time       14648 non-null  int64
#  3   updated    14648 non-null  int64
#  4   tz         0 non-null      object
#  5   url        14648 non-null  object
#  6   detail     14648 non-null  object
#  7   felt       2600 non-null   float64
#  8   cdi        2600 non-null   float64
#  9   mmi        534 non-null    float64
#  10  alert      232 non-null    object
#  11  status     14648 non-null  object
#  12  tsunami    14648 non-null  int64
#  13  sig        14648 non-null  int64
#  14  net        14648 non-null  object
#  15  code       14648 non-null  object
#  16  ids        14648 non-null  object
#  17  sources    14648 non-null  object
#  18  types      14648 non-null  object
#  19  nst        5440 non-null   float64
#  20  dmin       4794 non-null   float64
#  21  rms        13640 non-null  float64
#  22  gap        8614 non-null   float64
#  23  magType    14648 non-null  object
#  24  type       14648 non-null  object
#  25  title      14648 non-null  object
#  26  latitude   14648 non-null  float64
#  27  longitude  14648 non-null  float64
# dtypes: float64(10), int64(4), object(14)
# memory usage: 3.1+ MB

# %% [markdown]
# # Japan

# %%
# URL de la API
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query'

# Parámetros de la consulta
params = {
    'format': 'geojson',
    'starttime': '1990-01-01',
    'endtime': '2023-06-28',
    'minmagnitude': '2.5',
    'minlatitude': '28.691',
    'maxlatitude': '47.458',
    'minlongitude': '125.859',
    'maxlongitude': '156.445',
    'limit': 20000
}

# Realizar la solicitud GET a la API
response = requests.get(url, params=params)

# Obtener los datos en formato JSON
data = response.json()

# Crear una lista vacía para almacenar los registros
records = []

# Recorrer los eventos y extraer los parámetros
for event in data['features']:
    properties = event['properties']
    latitude = event['geometry']['coordinates'][1]
    longitude = event['geometry']['coordinates'][0]
    records.append(properties)

for event in data['features']:
    properties = event['properties']
    coordinates = event['geometry']['coordinates']
    properties['latitude'] = coordinates[1]
    properties['longitude'] = coordinates[0]
    records.append(properties)


# Crear el DataFrame
df_Japan = pd.DataFrame(records)


df_Japan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mag        40000 non-null  float64
#  1   place      39834 non-null  object
#  2   time       40000 non-null  int64
#  3   updated    40000 non-null  int64
#  4   tz         0 non-null      object
#  5   url        40000 non-null  object
#  6   detail     40000 non-null  object
#  7   felt       6388 non-null   float64
#  8   cdi        6388 non-null   float64
#  9   mmi        1046 non-null   float64
#  10  alert      632 non-null    object
#  11  status     40000 non-null  object
#  12  tsunami    40000 non-null  int64
#  13  sig        40000 non-null  int64
#  14  net        40000 non-null  object
#  15  code       40000 non-null  object
#  16  ids        40000 non-null  object
#  17  sources    40000 non-null  object
#  18  types      40000 non-null  object
#  19  nst        23684 non-null  float64
#  20  dmin       18706 non-null  float64
#  21  rms        38780 non-null  float64
#  22  gap        39992 non-null  float64
#  23  magType    40000 non-null  object
#  24  type       40000 non-null  object
#  25  title      40000 non-null  object
#  26  latitude   40000 non-null  float64
#  27  longitude  40000 non-null  float64
# dtypes: float64(10), int64(4), object(14)
# memory usage: 8.5+ MB

# %% [markdown]
# # EEUU

# %%
# URL de la API
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query'

# Parámetros de la consulta
params = {
    'format': 'geojson',
    'starttime': '1990-01-01',
    'endtime': '2023-06-28',
    'minmagnitude': '2.5',
    'minlatitude': '12.555',
    'maxlatitude': '75.141',
    'minlongitude': '182.813',
    'maxlongitude': '315',
    'limit': 20000
}

# Realizar la solicitud GET a la API
response = requests.get(url, params=params)

# Obtener los datos en formato JSON
data = response.json()

# Crear una lista vacía para almacenar los registros
records = []

# Recorrer los eventos y extraer los parámetros
for event in data['features']:
    properties = event['properties']
    latitude = event['geometry']['coordinates'][1]
    longitude = event['geometry']['coordinates'][0]
    records.append(properties)

for event in data['features']:
    properties = event['properties']
    coordinates = event['geometry']['coordinates']
    properties['latitude'] = coordinates[1]
    properties['longitude'] = coordinates[0]
    records.append(properties)

# Crear el DataFrame
df_EEUU = pd.DataFrame(records)
df_EEUU.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mag        40000 non-null  float64
#  1   place      39246 non-null  object
#  2   time       40000 non-null  int64
#  3   updated    40000 non-null  int64
#  4   tz         0 non-null      object
#  5   url        40000 non-null  object
#  6   detail     40000 non-null  object
#  7   felt       10414 non-null  float64
#  8   cdi        10414 non-null  float64
#  9   mmi        3466 non-null   float64
#  10  alert      620 non-null    object
#  11  status     40000 non-null  object
#  12  tsunami    40000 non-null  int64
#  13  sig        40000 non-null  int64
#  14  net        40000 non-null  object
#  15  code       40000 non-null  object
#  16  ids        40000 non-null  object
#  17  sources    40000 non-null  object
#  18  types      40000 non-null  object
#  19  nst        27552 non-null  float64
#  20  dmin       28428 non-null  float64
#  21  rms        39998 non-null  float64
#  22  gap        33566 non-null  float64
#  23  magType    40000 non-null  object
#  24  type       40000 non-null  object
#  25  title      40000 non-null  object
#  26  latitude   40000 non-null  float64
#  27  longitude  40000 non-null  float64
# dtypes: float64(10), int64(4), object(14)
# memory usage: 8.5+ MB

# %%
# Unimos todos los data en uno solo Dataframe
df_sismos = pd.concat([df_Colombia, df_EEUU, df_Japan], ignore_index=True)

# Crear un csv con la data original
df_sismos.to_csv('../DataSet/data_sismos_original.csv', index=False)

# %%
df_sismos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94648 entries, 0 to 94647
# Data columns (total 28 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mag        94648 non-null  float64
#  1   place      93696 non-null  object
#  2   time       94648 non-null  int64
#  3   updated    94648 non-null  int64
#  4   tz         0 non-null      object
#  5   url        94648 non-null  object
#  6   detail     94648 non-null  object
#  7   felt       19402 non-null  float64
#  8   cdi        19402 non-null  float64
#  9   mmi        5046 non-null   float64
#  10  alert      1484 non-null   object
#  11  status     94648 non-null  object
#  12  tsunami    94648 non-null  int64
#  13  sig        94648 non-null  int64
#  14  net        94648 non-null  object
#  15  code       94648 non-null  object
#  16  ids        94648 non-null  object
#  17  sources    94648 non-null  object
#  18  types      94648 non-null  object
#  19  nst        56676 non-null  float64
#  20  dmin       51928 non-null  float64
#  21  rms        92418 non-null  float64
#  22  gap        82172 non-null  float64
#  23  magType    94648 non-null  object
#  24  type       94648 non-null  object
#  25  title      94648 non-null  object
#  26  latitude   94648 non-null  float64
#  27  longitude  94648 non-null  float64
# dtypes: float64(10), int64(4), object(14)
# memory usage: 20.2+ MB

# %%
# Damos formato de fecha a la columna "time"
df_sismos["time"] = pd.to_datetime(df_sismos["time"], unit= "ms")
 

# Damos formato de fecha a la columna "time"
df_sismos["updated"] = pd.to_datetime(df_sismos["updated"], unit= "ms")

# %%
# Quitemos los nulos
df_sismos = df_sismos[["time", "mag", "cdi", "gap", "latitude", "longitude", "place", "ids"]]
df_sismos = df_sismos.dropna()
df_sismos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17956 entries, 0 to 94593
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       17956 non-null  datetime64[ns]
#  1   mag        17956 non-null  float64
#  2   cdi        17956 non-null  float64
#  3   gap        17956 non-null  float64
#  4   latitude   17956 non-null  float64
#  5   longitude  17956 non-null  float64
#  6   place      17956 non-null  object
#  7   ids        17956 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(2)
# memory usage: 1.2+ MB

# %%
# Creamos las columnas con "Pais" y con "Region"

# Crear una lista de tuplas de coordenadas (latitud, longitud)
coordinates = list(zip(df_sismos['latitude'], df_sismos['longitude']))

# Realizar la búsqueda inversa de las coordenadas
results = rg.search(coordinates)

# Obtener la lista de prefecturas a partir de los resultados
prefectures = [result['admin1'] if result['admin1'] != '' else 'Desconocido' for result in results]
countries = [result['cc'] if result['cc'] != '' else 'Desconocido' for result in results]
# Agregar la columna "region" al DataFrame
df_sismos['Region'] = prefectures
df_sismos['Pais'] = countries
df_sismos.info()
# Out:
# Loading formatted geocoded file...
# <class 'pandas.core.frame.DataFrame'>
# Index: 17956 entries, 0 to 94593
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       17956 non-null  datetime64[ns]
#  1   mag        17956 non-null  float64
#  2   cdi        17956 non-null  float64
#  3   gap        17956 non-null  float64
#  4   latitude   17956 non-null  float64
#  5   longitude  17956 non-null  float64
#  6   place      17956 non-null  object
#  7   ids        17956 non-null  object
#  8   Region     17956 non-null  object
#  9   Pais       17956 non-null  object
# dtypes: datetime64[ns](1), float64(5), object(4)
# memory usage: 1.5+ MB

# %%
# Listado de valores a eliminar en la columna 'Col1'
paises_permitidos = ['CO', 'US', 'JP']

# Eliminar las filas donde los valores de 'Pais' no coinciden con el listado
df_sismos = df_sismos[df_sismos['Pais'].isin(paises_permitidos)]

# Renombramos las columnas
nuevos_nombres = {'time': "Fecha", 'mag': "Magnitud", 'cdi': "Intensidad", 'gap': "GAP", 'latitude': "Latitud", 'longitude': "Longitud", 'place': "Lugar", 'ids': "Id", 'Region': 'Region' , 'Pais': 'Pais'}
df_sismos.columns = nuevos_nombres.values()


# Creamos un csv df_completo
df_sismos.to_csv('../DataSet/data_sismos_normalizado.csv', index=False)


# Mostrar el DataFrame resultante
print(df_sismos)
# Out:
#                         Fecha  Magnitud  Intensidad    GAP  Latitud  Longitud
# 10    2023-06-10 06:53:57.656       4.3         3.1   98.0   3.8178  -76.4890  \
# 15    2023-05-28 15:45:57.185       5.2         4.2   39.0   6.6964  -73.0303
# 26    2023-05-22 17:14:14.864       4.5         3.1   64.0   4.3829  -76.2681
# 31    2023-05-14 16:43:09.036       4.6         2.2   43.0   6.8463  -73.0895
# 32    2023-05-14 06:04:17.791       4.8         3.7  131.0   4.0397  -73.7077
# ...                       ...       ...         ...    ...      ...       ...
# 94464 2007-04-01 02:51:05.300       5.7         2.7   23.9  32.3490  137.6070
# 94516 2007-03-25 09:11:45.210       5.2         5.4   66.1  37.2640  136.6900
# 94528 2007-03-25 00:41:57.820       6.7         7.4   23.9  37.3360  136.5880
# 94552 2007-03-18 01:25:24.110       5.5         3.1   77.0  42.1590  144.0040
# 94593 2007-03-08 05:03:32.260       6.1         2.7   24.7  29.9080  140.2040
#
#                                 Lugar
# 10       3 km E of Restrepo, Colombia  \
# 15        1 km W of Aratoca, Colombia
# 26     10 km WNW of Bolívar, Colombia
# 31                  northern Colombia
# 32       8 km NE of Acacías, Colombia
# ...                               ...
# 94464      215 km SE of Shing?, Japan
# 94516        34 km NW of Nanao, Japan
# 94528        46 km NW of Nanao, Japan
# 94552     95 km SSW of Kushiro, Japan
# 94593       Izu Islands, Japan region
#
#                                                       Id           Region Pais
# 10                                          ,us7000k7li,  Valle del Cauca   CO
# 15                                          ,us7000k4mu,        Santander   CO
# 26                                          ,us6000kdxg,  Valle del Cauca   CO
# 31                                          ,us6000kbvy,        Santander   CO
# 32                                          ,us6000kbsg,             Meta   CO
# ...                                                  ...              ...  ...
# 94464  ,us2007aqae,usp000f817,gcmtc200704010251a,gcmt...         Wakayama   JP
# 94516  ,usp000f7cd,us2007aia3,gcmtc200703250911a,gcmt...         Ishikawa   JP
# 94528  ,us2007aiae,atlas20070325004100,atlas200703250...         Ishikawa   JP
# 94552  ,usp000f6wu,us2007abae,gcmtc200703180125a,gcmt...         Hokkaido   JP
# 94593  ,us2007zraj,usp000f6aj,choy20070308050332,gcmt...         Shizuoka   JP
#
# [13430 rows x 10 columns]
