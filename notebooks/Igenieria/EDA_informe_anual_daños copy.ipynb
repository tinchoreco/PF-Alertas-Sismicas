# %%
import requests
import pandas as pd
import csv
import datetime

# %% [markdown]
# https://public.emdat.be/data <br>
# datos sobre fallecidos por año en todos los países

# %%
df = pd.read_csv('../../DataSet/processed/emdat_CO_EU_JP_2023_07_05.csv')
df
# Out:
#      Year  Disaster Subsubtype  ISO  \
# 0    1906                  NaN  COL
# 1    1950                  NaN  COL
# 2    1962                  NaN  COL
# 3    1967                  NaN  COL
# 4    1970                  NaN  COL
# ..    ...                  ...  ...
# 141  1973                  NaN  USA
# 142  1973                  NaN  USA
# 143  1975                  NaN  USA
# 144  2022                  NaN  USA
# 145  2023                  NaN  JPN
#
#                                          Location Origin  Dis Mag Value  \
# 0                                          Tumako    NaN            9.0
# 1                            Santander, Amboledas    NaN            NaN
# 2                             Mistrato, Manizales    NaN            7.0
# 3    Neiva (Huila deparment); Rivera, San Antonio    NaN            7.0
# 4                          Pereira (Bahia Solano)    NaN            7.0
# ..                                            ...    ...            ...
# 141                           Oxnard (California)    NaN            6.0
# 142                                  Hilo (Hawai)    NaN            7.0
# 143                      Pocatello valley (Idaho)    NaN            6.0
# 144                  Humboldt County (California)    NaN            6.0
# 145                                      Ishikawa    NaN            6.0
#
#     Latitude Longitude Local Time        date  ... Total Deaths  No Injured  \
# 0     1.51 N  78.46 W         NaN  1906-01-31  ...        400.0         NaN
# 1        7.8     -72.5      21:35  1950-07-08  ...        211.0         NaN
# 2      5.173   -76.352      13:53  1962-07-30  ...         47.0       300.0
# 3      2.849   -74.798      10:24  1967-02-09  ...         61.0       200.0
# 4      6.375   -77.438      22:38  1970-09-25  ...          NaN         6.0
# ..       ...       ...        ...         ...  ...          ...         ...
# 141     34.1      -119      06:45  1973-02-21  ...          NaN         NaN
# 142   19.936  -155.098      10:26  1973-04-26  ...          NaN        11.0
# 143    42.06   -122.55      20:31  1975-03-27  ...          NaN         NaN
# 144   40.525   124.423      02:34  2022-12-20  ...          2.0        12.0
# 145      NaN       NaN      14:42  2023-05-06  ...          1.0        34.0
#
#      No Affected  No Homeless  Total Affected  Insured Damages US$  \
# 0            NaN          NaN             NaN                  NaN
# 1            NaN      40000.0         40000.0                  NaN
# 2            NaN          NaN           300.0                  NaN
# 3        40000.0          NaN         40200.0                  NaN
# 4         3000.0          NaN          3006.0                  NaN
# ..           ...          ...             ...                  ...
# 141          NaN          NaN             NaN                  NaN
# 142          NaN          NaN            11.0                  NaN
# 143       1560.0          NaN          1560.0                  NaN
# 144          NaN          NaN            12.0                  NaN
# 145       1050.0          NaN          1084.0                  NaN
#
#      Insured Damages US$(2021)  Total Damages US$  Total Damages US$(2021)  \
# 0                          NaN                NaN                      NaN
# 1                          NaN             5000.0                  60683.0
# 2                          NaN                NaN                      NaN
# 3                          NaN              600.0                   5264.0
# 4                          NaN              400.0                   3015.0
# ..                         ...                ...                      ...
# 141                        NaN             1000.0                   6591.0
# 142                        NaN             5750.0                  37900.0
# 143                        NaN             1000.0                   5438.0
# 144                        NaN           250000.0                 250000.0
# 145                        NaN                NaN                      NaN
#
#             CPI
# 0      3.077011
# 1      8.239552
# 2     10.336410
# 3     11.398527
# 4     13.266480
# ..          ...
# 141   15.171453
# 142   15.171453
# 143   18.389129
# 144  100.000000
# 145         NaN
#
# [146 rows x 21 columns]
